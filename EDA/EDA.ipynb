# %% [markdown]
# Importing libraries

# %%
# %pip install pandas 
# %pip install seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.0)
# Requirement already satisfied: pillow>=8 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd 
import seaborn as sns

# %%
df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_7864\2350612576.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")

# %% [markdown]
# See the data that has been imported

# %%
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# 1                         22           5:15:45 h   Roberto Echeverría
# 2                         22           5:16:44 h    Puro Trail Osorno
# 3                         22           5:34:13 h             Columbia
# 4                         22           5:54:14 h       Baguales Trail
# 5                         22           6:25:01 h                  NaN
# 6                         22           6:28:00 h        Los Patagones
# 7                         22           6:32:24 h       Reaktiva Chile
# 8                         22           6:39:08 h    Puro Trail Osorno
# 9                         22           6:45:11 h  Marlene Flores Team
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# 0             CHI                 1978.0              M                  M35
# 1             CHI                 1981.0              M                  M35
# 2             CHI                 1987.0              M                  M23
# 3             ARG                 1976.0              M                  M40
# 4             CHI                 1992.0              M                  M23
# 5             ARG                 1974.0              M                  M40
# 6             ARG                 1979.0              F                  W35
# 7             CHI                 1967.0              F                  W50
# 8             CHI                 1985.0              M                  M23
# 9             CHI                 1976.0              M                  M40
#
#   Athlete average speed  Athlete ID
# 0                10.286           0
# 1                 9.501           1
# 2                 9.472           2
# 3                 8.976           3
# 4                 8.469           4
# 5                 7.792           5
# 6                 7.732           6
# 7                 7.645           7
# 8                 7.516           8
# 9                 7.404           9

# %%
df.shape
# Out:
# (7461195, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %% [markdown]
# Cleaning the Data
# Only want USA Races, 50K or 50Mi, 2020

# %% [markdown]
# Step 1 : Show 50Km or 50mi
# #50Km
# #50mi

# %%
df[df['Event distance/length']== '50km']
# Out:
#          Year of event Event dates                             Event name  \
# 0                 2018  06.01.2018                    Selva Costera (CHI)
# 1                 2018  06.01.2018                    Selva Costera (CHI)
# 2                 2018  06.01.2018                    Selva Costera (CHI)
# 3                 2018  06.01.2018                    Selva Costera (CHI)
# 4                 2018  06.01.2018                    Selva Costera (CHI)
# ...                ...         ...                                    ...
# 7461089           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461090           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461091           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461092           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461093           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 0                        50km                         22           4:51:39 h
# 1                        50km                         22           5:15:45 h
# 2                        50km                         22           5:16:44 h
# 3                        50km                         22           5:34:13 h
# 4                        50km                         22           5:54:14 h
# ...                       ...                        ...                 ...
# 7461089                  50km                          6           4:19:56 h
# 7461090                  50km                          6           4:28:57 h
# 7461091                  50km                          6           4:46:39 h
# 7461092                  50km                          6           4:47:39 h
# 7461093                  50km                          6           5:58:16 h
#
#                Athlete club Athlete country  Athlete year of birth  \
# 0                     Tnfrc             CHI                 1978.0
# 1        Roberto Echeverría             CHI                 1981.0
# 2         Puro Trail Osorno             CHI                 1987.0
# 3                  Columbia             ARG                 1976.0
# 4            Baguales Trail             CHI                 1992.0
# ...                     ...             ...                    ...
# 7461089                *QLD             AUS                 1956.0
# 7461090                *QLD             AUS                 1954.0
# 7461091                *QLD             AUS                 1951.0
# 7461092                *QLD             AUS                 1939.0
# 7461093                *QLD             AUS                 1938.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 0                    M                  M35                10.286           0
# 1                    M                  M35                 9.501           1
# 2                    M                  M23                 9.472           2
# 3                    M                  M40                 8.976           3
# 4                    M                  M23                 8.469           4
# ...                ...                  ...                   ...         ...
# 7461089              F                  W35               11541.0     1046326
# 7461090              M                  M40               11154.0     1070007
# 7461091              M                  M40               10466.0      345672
# 7461092              M                  M55               10429.0     1082443
# 7461093              F                  W55                8374.0     1082581
#
# [1522609 rows x 13 columns]

# %% [markdown]
# Combine 50K/50mi with isin

# %%
df[(df['Event distance/length'].isin(['50Km','50mi']))  &   (df['Year of event'] == 2020)]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2757700           2020      08.10.2020
# 2757701           2020      08.10.2020
# 2757702           2020      08.10.2020
# 2757703           2020      08.10.2020
# 2757704           2020      08.10.2020
#
#                                                Event name  \
# 2538571           Taipei 48hr Ultra Marathon - 50mi (TPE)
# 2538572           Taipei 48hr Ultra Marathon - 50mi (TPE)
# 2538573           Taipei 48hr Ultra Marathon - 50mi (TPE)
# 2538574           Taipei 48hr Ultra Marathon - 50mi (TPE)
# 2538575           Taipei 48hr Ultra Marathon - 50mi (TPE)
# ...                                                   ...
# 2757700  Täby Extreme Challenge 50 miles - Thursday (SWE)
# 2757701  Täby Extreme Challenge 50 miles - Thursday (SWE)
# 2757702  Täby Extreme Challenge 50 miles - Thursday (SWE)
# 2757703  Täby Extreme Challenge 50 miles - Thursday (SWE)
# 2757704  Täby Extreme Challenge 50 miles - Thursday (SWE)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2538571                  50mi                         38           7:34:19 h
# 2538572                  50mi                         38           7:43:50 h
# 2538573                  50mi                         38           8:04:40 h
# 2538574                  50mi                         38           8:30:49 h
# 2538575                  50mi                         38           8:34:47 h
# ...                       ...                        ...                 ...
# 2757700                  50mi                         13          10:28:30 h
# 2757701                  50mi                         13          10:49:55 h
# 2757702                  50mi                         13          12:08:13 h
# 2757703                  50mi                         13          12:33:04 h
# 2757704                  50mi                         13          12:47:26 h
#
#                     Athlete club Athlete country  Athlete year of birth  \
# 2538571                      日本隊             JPN                 1965.0
# 2538572                      NaN             AUS                 1974.0
# 2538573                      NaN             TPE                 1976.0
# 2538574                台灣大腳ㄚ長跑協會             TPE                 1969.0
# 2538575                      NaN             TPE                 1964.0
# ...                          ...             ...                    ...
# 2757700        Sweden Runners IF             SWE                 1969.0
# 2757701  Stockholm Gerillalöpare             SWE                 1993.0
# 2757702                      ÅTF             GBR                 1980.0
# 2757703        Team Skavsåret IF             SWE                 1976.0
# 2757704              CRD Runnerd             SWE                 1980.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 2538571              M                  M50                10.627       53107
# 2538572              M                  M45                10.409        8785
# 2538573              M                  M40                 9.962        4502
# 2538574              F                  W50                 9.452       63964
# 2538575              M                  M55                 9.379        4485
# ...                ...                  ...                   ...         ...
# 2757700              M                  M50                 7.682      859639
# 2757701              M                  M23                 7.429      859640
# 2757702              M                  M40                  6.63      859641
# 2757703              M                  M40                 6.411       21883
# 2757704              F                  W40                 6.291      859642
#
# [7605 rows x 13 columns]

# %%
df[(df['Event name'] == 'Everglades 50 Mile Ultra Run (USA)')]['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)
# Out:
# 51923      USA
# 51924      USA
# 51925      USA
# 51926      USA
# 51927      USA
#           ...
# 6417091    USA
# 6417092    USA
# 6417093    USA
# 6417094    USA
# 6417095    USA
# Name: Event name, Length: 338, dtype: object

# %%
df[df['Event name'].str[-5:] == '(USA)']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...                                                ...                   ...
# 7461181               Avalon Benefit 50-Mile Run (USA)                  50mi
# 7461182               Avalon Benefit 50-Mile Run (USA)                  50mi
# 7461183               Avalon Benefit 50-Mile Run (USA)                  50mi
# 7461184               Avalon Benefit 50-Mile Run (USA)                  50mi
# 7461185               Avalon Benefit 50-Mile Run (USA)                  50mi
#
#          Event number of finishers Athlete performance      Athlete club  \
# 55                               9           9:53:05 h  *Middleville, MI
# 56                               9          11:09:35 h     *Waterloo, ON
# 57                               9          11:33:00 h    *Kitchener, ON
# 58                               9          11:38:17 h        *Utica, MI
# 59                               9          11:56:35 h   *Grass Lake, MI
# ...                            ...                 ...               ...
# 7461181                         92          11:59:37 h               NaN
# 7461182                         92          12:01:41 h               NaN
# 7461183                         92          12:03:26 h               NaN
# 7461184                         92          12:03:26 h               NaN
# 7461185                         92          12:05:59 h               NaN
#
#         Athlete country  Athlete year of birth Athlete gender  \
# 55                  USA                 1983.0              M
# 56                  CAN                 1977.0              F
# 57                  CAN                 1976.0              M
# 58                  USA                 1986.0              M
# 59                  USA                 1988.0              M
# ...                 ...                    ...            ...
# 7461181             USA                 1941.0              M
# 7461182             USA                 1932.0              M
# 7461183             USA                 1934.0              F
# 7461184             USA                 1951.0              F
# 7461185             USA                 1947.0              F
#
#         Athlete age category Athlete average speed  Athlete ID
# 55                       M23                 8.141          55
# 56                       W40                 7.211          56
# 57                       M40                 6.967          57
# 58                       M23                 6.914          58
# 59                       M23                 6.738          59
# ...                      ...                   ...         ...
# 7461181                  M50                6709.0     1045603
# 7461182                  M60                6690.0     1070463
# 7461183                  W60                6674.0      416139
# 7461184                  W40                6674.0     1098098
# 7461185                  W45                6650.0     1626367
#
# [1408416 rows x 13 columns]

# %% [markdown]
# Combining all the code together

# %%
df[(df['Event distance/length'].isin(['50Km','50mi']))  &   (df['Year of event'] == 2020)  & (df['Event name'].str[-5:] == '(USA)')]
# Out:
#          Year of event Event dates                       Event name  \
# 2542134           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542135           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542136           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542137           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542138           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# ...                ...         ...                              ...
# 2757274           2020  10.10.2020  Old Cascadia 50 Mile Race (USA)
# 2757275           2020  10.10.2020  Old Cascadia 50 Mile Race (USA)
# 2757276           2020  10.10.2020  Old Cascadia 50 Mile Race (USA)
# 2757277           2020  10.10.2020  Old Cascadia 50 Mile Race (USA)
# 2757278           2020  10.10.2020  Old Cascadia 50 Mile Race (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2542134                  50mi                         10           8:51:11 h
# 2542135                  50mi                         10          11:37:15 h
# 2542136                  50mi                         10          11:59:00 h
# 2542137                  50mi                         10          12:04:40 h
# 2542138                  50mi                         10          12:26:20 h
# ...                       ...                        ...                 ...
# 2757274                  50mi                         54          16:05:34 h
# 2757275                  50mi                         54          16:22:12 h
# 2757276                  50mi                         54          16:46:54 h
# 2757277                  50mi                         54          16:46:56 h
# 2757278                  50mi                         54          17:51:56 h
#
#               Athlete club Athlete country  Athlete year of birth  \
# 2542134       *Phoenix, AZ             USA                 1987.0
# 2542135       *Phoenix, AZ             USA                 1985.0
# 2542136            *London             GBR                 1988.0
# 2542137           *Fpo, AZ             USA                 1979.0
# 2542138    *Saint Paul, MN             USA                 1997.0
# ...                    ...             ...                    ...
# 2757274   *Leavenworth, WA             USA                 1977.0
# 2757275        *Eureka, CA             USA                 1964.0
# 2757276       *Edmonds, WA             USA                 1993.0
# 2757277  *Lake Stevens, WA             USA                 1977.0
# 2757278        *Novato, CA             USA                 1957.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 2542134              M                  M23                 9.089       86674
# 2542135              M                  M23                 6.924       53268
# 2542136              M                  M23                 6.715      778567
# 2542137              M                  M40                 6.662      209242
# 2542138              M                 MU23                 6.469      810742
# ...                ...                  ...                   ...         ...
# 2757274              M                  M40                     5       25686
# 2757275              M                  M55                 4.916      346689
# 2757276              M                  M23                 4.795      653366
# 2757277              F                  W40                 4.795       54286
# 2757278              M                  M60                 4.504      241915
#
# [5699 rows x 13 columns]

# %%
df2 = df[(df['Event distance/length'].isin(['50Km','50mi']))  &   (df['Year of event'] == 2020)  & (df['Event name'].str[-5:] == '(USA)')]

# %%
df2.head(10)
# Out:
#          Year of event Event dates                       Event name  \
# 2542134           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542135           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542136           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542137           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542138           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542139           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542140           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542141           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542142           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542143           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2542134                  50mi                         10           8:51:11 h
# 2542135                  50mi                         10          11:37:15 h
# 2542136                  50mi                         10          11:59:00 h
# 2542137                  50mi                         10          12:04:40 h
# 2542138                  50mi                         10          12:26:20 h
# 2542139                  50mi                         10          12:30:10 h
# 2542140                  50mi                         10          12:47:18 h
# 2542141                  50mi                         10          13:56:23 h
# 2542142                  50mi                         10          13:56:26 h
# 2542143                  50mi                         10          14:15:39 h
#
#             Athlete club Athlete country  Athlete year of birth  \
# 2542134     *Phoenix, AZ             USA                 1987.0
# 2542135     *Phoenix, AZ             USA                 1985.0
# 2542136          *London             GBR                 1988.0
# 2542137         *Fpo, AZ             USA                 1979.0
# 2542138  *Saint Paul, MN             USA                 1997.0
# 2542139    *Prescott, AZ             USA                 1965.0
# 2542140     *Phoenix, AZ             USA                 1979.0
# 2542141     *Phoenix, AZ             USA                 1974.0
# 2542142   *Las Vegas, NV             USA                 1977.0
# 2542143     *Phoenix, AZ             USA                 1974.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 2542134              M                  M23                 9.089       86674
# 2542135              M                  M23                 6.924       53268
# 2542136              M                  M23                 6.715      778567
# 2542137              M                  M40                 6.662      209242
# 2542138              M                 MU23                 6.469      810742
# 2542139              M                  M50                 6.436       46996
# 2542140              F                  W40                 6.292       47250
# 2542141              M                  M45                 5.773      344444
# 2542142              M                  M40                 5.772      155125
# 2542143              F                  W45                 5.643      183117

# %%
df2.shape
# Out:
# (5699, 13)

# %% [markdown]
# Remove USA from events name

# %%
df2['Event name'].str.split('(').str.get(0)
# Out:
# 2542134    Elephant Mountain 50 Mile
# 2542135    Elephant Mountain 50 Mile
# 2542136    Elephant Mountain 50 Mile
# 2542137    Elephant Mountain 50 Mile
# 2542138    Elephant Mountain 50 Mile
#                       ...
# 2757274    Old Cascadia 50 Mile Race
# 2757275    Old Cascadia 50 Mile Race
# 2757276    Old Cascadia 50 Mile Race
# 2757277    Old Cascadia 50 Mile Race
# 2757278    Old Cascadia 50 Mile Race
# Name: Event name, Length: 5699, dtype: object

# %%
df2['Event name'] = df2['Event name'].str.split('(').str.get(0)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_7864\3473829760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Event name'] = df2['Event name'].str.split('(').str.get(0)

# %%
df2.head()
# Out:
#          Year of event Event dates                  Event name  \
# 2542134           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542135           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542136           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542137           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542138           2020  01.02.2020  Elephant Mountain 50 Mile
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2542134                  50mi                         10           8:51:11 h
# 2542135                  50mi                         10          11:37:15 h
# 2542136                  50mi                         10          11:59:00 h
# 2542137                  50mi                         10          12:04:40 h
# 2542138                  50mi                         10          12:26:20 h
#
#             Athlete club Athlete country  Athlete year of birth  \
# 2542134     *Phoenix, AZ             USA                 1987.0
# 2542135     *Phoenix, AZ             USA                 1985.0
# 2542136          *London             GBR                 1988.0
# 2542137         *Fpo, AZ             USA                 1979.0
# 2542138  *Saint Paul, MN             USA                 1997.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 2542134              M                  M23                 9.089       86674
# 2542135              M                  M23                 6.924       53268
# 2542136              M                  M23                 6.715      778567
# 2542137              M                  M40                 6.662      209242
# 2542138              M                 MU23                 6.469      810742

# %% [markdown]
# Clean up Athlete Age

# %%
df2['athlete_age'] = 2020 - df2['Athlete year of birth']
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_7864\3897931444.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['athlete_age'] = 2020 - df2['Athlete year of birth']

# %% [markdown]
# Remove h from athlete performance

# %%
df2['Athlete performance'].str.split(' ').str.get(0)
# Out:
# 2542134     8:51:11
# 2542135    11:37:15
# 2542136    11:59:00
# 2542137    12:04:40
# 2542138    12:26:20
#              ...
# 2757274    16:05:34
# 2757275    16:22:12
# 2757276    16:46:54
# 2757277    16:46:56
# 2757278    17:51:56
# Name: Athlete performance, Length: 5699, dtype: object

# %%
df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_7864\2477507555.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)

# %%
df2.head(5)
# Out:
#          Year of event Event dates                  Event name  \
# 2542134           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542135           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542136           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542137           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542138           2020  01.02.2020  Elephant Mountain 50 Mile
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2542134                  50mi                         10             8:51:11
# 2542135                  50mi                         10            11:37:15
# 2542136                  50mi                         10            11:59:00
# 2542137                  50mi                         10            12:04:40
# 2542138                  50mi                         10            12:26:20
#
#             Athlete club Athlete country  Athlete year of birth  \
# 2542134     *Phoenix, AZ             USA                 1987.0
# 2542135     *Phoenix, AZ             USA                 1985.0
# 2542136          *London             GBR                 1988.0
# 2542137         *Fpo, AZ             USA                 1979.0
# 2542138  *Saint Paul, MN             USA                 1997.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID  \
# 2542134              M                  M23                 9.089       86674
# 2542135              M                  M23                 6.924       53268
# 2542136              M                  M23                 6.715      778567
# 2542137              M                  M40                 6.662      209242
# 2542138              M                 MU23                 6.469      810742
#
#          athlete_age
# 2542134         33.0
# 2542135         35.0
# 2542136         32.0
# 2542137         41.0
# 2542138         23.0

# %% [markdown]
# Drop columns : Athlete Club, Athlete Country, Athlete Year of Birth, Athlete Age category

# %%
df2 = df2.drop(['Athlete club','Athlete country', 'Athlete year of birth', 'Athlete age category'], axis = 1)

# %%
df2.head()
# Out:
#          Year of event Event dates                  Event name  \
# 2542134           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542135           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542136           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542137           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542138           2020  01.02.2020  Elephant Mountain 50 Mile
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2542134                  50mi                         10             8:51:11
# 2542135                  50mi                         10            11:37:15
# 2542136                  50mi                         10            11:59:00
# 2542137                  50mi                         10            12:04:40
# 2542138                  50mi                         10            12:26:20
#
#         Athlete gender Athlete average speed  Athlete ID  athlete_age
# 2542134              M                 9.089       86674         33.0
# 2542135              M                 6.924       53268         35.0
# 2542136              M                 6.715      778567         32.0
# 2542137              M                 6.662      209242         41.0
# 2542138              M                 6.469      810742         23.0

# %% [markdown]
# Clean up Null Values

# %%
df2.isna().sum()
# Out:
# Year of event                 0
# Event dates                   0
# Event name                    0
# Event distance/length         0
# Event number of finishers     0
# Athlete performance           0
# Athlete gender                0
# Athlete average speed         0
# Athlete ID                    0
# athlete_age                  42
# dtype: int64

# %%
df2[df2['athlete_age'].isna()==1]
# Out:
#          Year of event     Event dates                           Event name  \
# 2552459           2020      19.01.2020        Big Bend 50 - Borderland 50M
# 2552462           2020      19.01.2020        Big Bend 50 - Borderland 50M
# 2552465           2020      19.01.2020        Big Bend 50 - Borderland 50M
# 2552472           2020      19.01.2020        Big Bend 50 - Borderland 50M
# 2591396           2020      14.03.2020     Bel Monte 50 Mile Endurance Run
# 2591418           2020      14.03.2020     Bel Monte 50 Mile Endurance Run
# 2591430           2020      14.03.2020     Bel Monte 50 Mile Endurance Run
# 2591434           2020      14.03.2020     Bel Monte 50 Mile Endurance Run
# 2591441           2020      14.03.2020     Bel Monte 50 Mile Endurance Run
# 2591444           2020      14.03.2020     Bel Monte 50 Mile Endurance Run
# 2591447           2020      14.03.2020     Bel Monte 50 Mile Endurance Run
# 2591451           2020      14.03.2020     Bel Monte 50 Mile Endurance Run
# 2591459           2020      14.03.2020     Bel Monte 50 Mile Endurance Run
# 2591467           2020      14.03.2020     Bel Monte 50 Mile Endurance Run
# 2591468           2020      14.03.2020     Bel Monte 50 Mile Endurance Run
# 2627687           2020  08.-09.02.2020    Lake Okeechobee Scenic Trail Run
# 2688312           2020      08.08.2020  Ashley 50 Mile Ultra and Relay Run
# 2688314           2020      08.08.2020  Ashley 50 Mile Ultra and Relay Run
# 2688317           2020      08.08.2020  Ashley 50 Mile Ultra and Relay Run
# 2713466           2020      21.11.2020                         JFK 50 Mile
# 2713524           2020      21.11.2020                         JFK 50 Mile
# 2713744           2020      21.11.2020                         JFK 50 Mile
# 2713948           2020      21.11.2020                         JFK 50 Mile
# 2731346           2020      31.10.2020               Mohican Trail 50 Mile
# 2731352           2020      31.10.2020               Mohican Trail 50 Mile
# 2731375           2020      31.10.2020               Mohican Trail 50 Mile
# 2731385           2020      31.10.2020               Mohican Trail 50 Mile
# 2731400           2020      31.10.2020               Mohican Trail 50 Mile
# 2731401           2020      31.10.2020               Mohican Trail 50 Mile
# 2731405           2020      31.10.2020               Mohican Trail 50 Mile
# 2731407           2020      31.10.2020               Mohican Trail 50 Mile
# 2731410           2020      31.10.2020               Mohican Trail 50 Mile
# 2731411           2020      31.10.2020               Mohican Trail 50 Mile
# 2731413           2020      31.10.2020               Mohican Trail 50 Mile
# 2731414           2020      31.10.2020               Mohican Trail 50 Mile
# 2731418           2020      31.10.2020               Mohican Trail 50 Mile
# 2731419           2020      31.10.2020               Mohican Trail 50 Mile
# 2739009           2020  24.-25.10.2020                 Cactus Rose 50 Mile
# 2749869           2020      17.10.2020  MuleSkinner Endurance 50 Mile Race
# 2755985           2020      10.10.2020      Man Against Horse 50 Mile Race
# 2755994           2020      10.10.2020      Man Against Horse 50 Mile Race
# 2755997           2020      10.10.2020      Man Against Horse 50 Mile Race
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2552459                  50mi                         15             8:02:53
# 2552462                  50mi                         15             9:24:38
# 2552465                  50mi                         15             9:42:51
# 2552472                  50mi                         15            13:36:45
# 2591396                  50mi                         87            10:17:53
# 2591418                  50mi                         87            12:01:51
# 2591430                  50mi                         87            12:26:57
# 2591434                  50mi                         87            12:34:31
# 2591441                  50mi                         87            12:49:22
# 2591444                  50mi                         87            12:54:14
# 2591447                  50mi                         87            13:01:32
# 2591451                  50mi                         87            13:03:18
# 2591459                  50mi                         87            13:13:32
# 2591467                  50mi                         87            13:31:49
# 2591468                  50mi                         87            13:31:49
# 2627687                  50mi                          5            10:12:34
# 2688312                  50mi                          8             7:45:00
# 2688314                  50mi                          8             9:01:00
# 2688317                  50mi                          8             9:32:00
# 2713466                  50mi                        636             8:59:27
# 2713524                  50mi                        636             9:50:08
# 2713744                  50mi                        636            11:38:53
# 2713948                  50mi                        636            13:12:24
# 2731346                  50mi                         97            11:05:54
# 2731352                  50mi                         97            11:23:38
# 2731375                  50mi                         97            12:35:55
# 2731385                  50mi                         97            13:00:20
# 2731400                  50mi                         97            15:29:56
# 2731401                  50mi                         97            15:34:27
# 2731405                  50mi                         97            15:37:38
# 2731407                  50mi                         97            15:50:18
# 2731410                  50mi                         97            15:55:32
# 2731411                  50mi                         97            16:02:26
# 2731413                  50mi                         97            17:26:04
# 2731414                  50mi                         97            17:48:32
# 2731418                  50mi                         97            19:44:16
# 2731419                  50mi                         97            20:19:36
# 2739009                  50mi                         47            18:16:43
# 2749869                  50mi                         27            11:55:05
# 2755985                  50mi                         23             9:03:25
# 2755994                  50mi                         23            10:37:00
# 2755997                  50mi                         23            12:30:00
#
#         Athlete gender Athlete average speed  Athlete ID  athlete_age
# 2552459              F                 9.998      813139          NaN
# 2552462              M                 8.551      813140          NaN
# 2552465              M                 8.283      813141          NaN
# 2552472              M                 5.911       67711          NaN
# 2591396              M                 7.814      820742          NaN
# 2591418              M                 6.688      820745          NaN
# 2591430              M                 6.464      820748          NaN
# 2591434              M                 6.399      820750          NaN
# 2591441              F                 6.275      820751          NaN
# 2591444              M                 6.236      820752          NaN
# 2591447              F                 6.178      820753          NaN
# 2591451              M                 6.164      647136          NaN
# 2591459              F                 6.084      820754          NaN
# 2591467              M                 5.947      688112          NaN
# 2591468              M                 5.947      820755          NaN
# 2627687              M                 7.882      828873          NaN
# 2688312              M                10.383      842079          NaN
# 2688314              M                 8.924      842080          NaN
# 2688317              F                 8.441      842081          NaN
# 2713466              M                  8.95        4033          NaN
# 2713524              M                 8.181        4033          NaN
# 2713744              M                 6.908        4033          NaN
# 2713948              M                 6.093        4033          NaN
# 2731346              M                  7.25      853923          NaN
# 2731352              M                 7.062      853924          NaN
# 2731375              M                 6.387      853928          NaN
# 2731385              M                 6.187      853930          NaN
# 2731400              F                 5.192      329074          NaN
# 2731401              M                 5.167      853934          NaN
# 2731405              F                 5.149      853935          NaN
# 2731407              M                 5.081      853936          NaN
# 2731410              M                 5.053      853938          NaN
# 2731411              F                 5.016      853939          NaN
# 2731413              M                 4.615      853940          NaN
# 2731414              M                 4.518      853941          NaN
# 2731418              F                 4.077      853943          NaN
# 2731419              F                 3.959      853944          NaN
# 2739009              M                 4.402        4033          NaN
# 2749869              M                 6.752      857957          NaN
# 2755985              M                 8.885      859462          NaN
# 2755994              M                 7.579      398583          NaN
# 2755997              M                 6.437      859465          NaN

# %%
df2 = df2.dropna()

# %%
df2.shape
# Out:
# (5657, 10)

# %% [markdown]
# Check for duplicate values

# %%
df2[df2.duplicated()== True]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, athlete_age]
# Index: []

# %% [markdown]
# Reset Index

# %%
df2.reset_index(drop = True)
# Out:
#       Year of event Event dates                  Event name  \
# 0              2020  01.02.2020  Elephant Mountain 50 Mile
# 1              2020  01.02.2020  Elephant Mountain 50 Mile
# 2              2020  01.02.2020  Elephant Mountain 50 Mile
# 3              2020  01.02.2020  Elephant Mountain 50 Mile
# 4              2020  01.02.2020  Elephant Mountain 50 Mile
# ...             ...         ...                         ...
# 5652           2020  10.10.2020  Old Cascadia 50 Mile Race
# 5653           2020  10.10.2020  Old Cascadia 50 Mile Race
# 5654           2020  10.10.2020  Old Cascadia 50 Mile Race
# 5655           2020  10.10.2020  Old Cascadia 50 Mile Race
# 5656           2020  10.10.2020  Old Cascadia 50 Mile Race
#
#      Event distance/length  Event number of finishers Athlete performance  \
# 0                     50mi                         10             8:51:11
# 1                     50mi                         10            11:37:15
# 2                     50mi                         10            11:59:00
# 3                     50mi                         10            12:04:40
# 4                     50mi                         10            12:26:20
# ...                    ...                        ...                 ...
# 5652                  50mi                         54            16:05:34
# 5653                  50mi                         54            16:22:12
# 5654                  50mi                         54            16:46:54
# 5655                  50mi                         54            16:46:56
# 5656                  50mi                         54            17:51:56
#
#      Athlete gender Athlete average speed  Athlete ID  athlete_age
# 0                 M                 9.089       86674         33.0
# 1                 M                 6.924       53268         35.0
# 2                 M                 6.715      778567         32.0
# 3                 M                 6.662      209242         41.0
# 4                 M                 6.469      810742         23.0
# ...             ...                   ...         ...          ...
# 5652              M                     5       25686         43.0
# 5653              M                 4.916      346689         56.0
# 5654              M                 4.795      653366         27.0
# 5655              F                 4.795       54286         43.0
# 5656              M                 4.504      241915         63.0
#
# [5657 rows x 10 columns]

# %% [markdown]
# Fix types

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                     int64
# athlete_age                  float64
# dtype: object

# %%
df2['athlete_age'].astype(int)
# Out:
# 2542134    33
# 2542135    35
# 2542136    32
# 2542137    41
# 2542138    23
#            ..
# 2757274    43
# 2757275    56
# 2757276    27
# 2757277    43
# 2757278    63
# Name: athlete_age, Length: 5657, dtype: int64

# %%
df2['athlete_age'] = df2['athlete_age'].astype(int)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_7864\2319086533.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['athlete_age'] = df2['athlete_age'].astype(int)

# %%
df2['Athlete average speed'] = df2['Athlete average speed'].astype(float)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_7864\501852820.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete average speed'] = df2['Athlete average speed'].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# athlete_age                    int64
# dtype: object

# %%
df2.head()
# Out:
#          Year of event Event dates                  Event name  \
# 2542134           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542135           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542136           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542137           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542138           2020  01.02.2020  Elephant Mountain 50 Mile
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2542134                  50mi                         10             8:51:11
# 2542135                  50mi                         10            11:37:15
# 2542136                  50mi                         10            11:59:00
# 2542137                  50mi                         10            12:04:40
# 2542138                  50mi                         10            12:26:20
#
#         Athlete gender  Athlete average speed  Athlete ID  athlete_age
# 2542134              M                  9.089       86674           33
# 2542135              M                  6.924       53268           35
# 2542136              M                  6.715      778567           32
# 2542137              M                  6.662      209242           41
# 2542138              M                  6.469      810742           23

# %% [markdown]
# Rename Columns

# %%
#Year of event                  int64
#Event dates                   object
#Event name                    object
#Event distance/length         object
#Event number of finishers      int64
#Athlete performance           object
#Athlete gender                object
#Athlete average speed        float64
#Athlete ID                     int64
#athlete_age                    int64

# %%
df2 = df2.rename(columns ={'Year of event': 'year' ,
                           'Event dates' : 'race_day',
                           'Event name' : 'race_name' ,                   
                           'Event distance/length' : 'race_length' ,        
                           'Event number of finishers' :'race_number_of_finishers',     
                           'Athlete performance' : 'athlete_performance',           
                           'Athlete gender' : 'athlete_gender',              
                           'Athlete average speed' : 'athlete_average_speed',        
                           'Athlete ID' : 'athlete_id'                   
                        })

# %%
df2.head()
# Out:
#          year    race_day                   race_name race_length  \
# 2542134  2020  01.02.2020  Elephant Mountain 50 Mile         50mi
# 2542135  2020  01.02.2020  Elephant Mountain 50 Mile         50mi
# 2542136  2020  01.02.2020  Elephant Mountain 50 Mile         50mi
# 2542137  2020  01.02.2020  Elephant Mountain 50 Mile         50mi
# 2542138  2020  01.02.2020  Elephant Mountain 50 Mile         50mi
#
#          race_number_of_finishers athlete_performance athlete_gender  \
# 2542134                        10             8:51:11              M
# 2542135                        10            11:37:15              M
# 2542136                        10            11:59:00              M
# 2542137                        10            12:04:40              M
# 2542138                        10            12:26:20              M
#
#          athlete_average_speed  athlete_id  athlete_age
# 2542134                  9.089       86674           33
# 2542135                  6.924       53268           35
# 2542136                  6.715      778567           32
# 2542137                  6.662      209242           41
# 2542138                  6.469      810742           23

# %% [markdown]
# Reorder Columns

# %%
df3 = df2[['race_day', 'race_name',	'race_length','race_number_of_finishers','athlete_id', 'athlete_gender', 'athlete_age', 'athlete_performance',	'athlete_average_speed'	, 	]]

# %%
df3.head()
# Out:
#            race_day                   race_name race_length  \
# 2542134  01.02.2020  Elephant Mountain 50 Mile         50mi
# 2542135  01.02.2020  Elephant Mountain 50 Mile         50mi
# 2542136  01.02.2020  Elephant Mountain 50 Mile         50mi
# 2542137  01.02.2020  Elephant Mountain 50 Mile         50mi
# 2542138  01.02.2020  Elephant Mountain 50 Mile         50mi
#
#          race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 2542134                        10       86674              M           33
# 2542135                        10       53268              M           35
# 2542136                        10      778567              M           32
# 2542137                        10      209242              M           41
# 2542138                        10      810742              M           23
#
#         athlete_performance  athlete_average_speed
# 2542134             8:51:11                  9.089
# 2542135            11:37:15                  6.924
# 2542136            11:59:00                  6.715
# 2542137            12:04:40                  6.662
# 2542138            12:26:20                  6.469

# %% [markdown]
# Finding Two races - Sarasota/ Everglades

# %%
df3[df3['race_name'] == 'Everglades 50 Mile Ultra Run ' ]
# Out:
#            race_day                      race_name race_length  \
# 2591476  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591477  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591478  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591479  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591480  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591481  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591482  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591483  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591484  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591485  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591486  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591487  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591488  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591489  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591490  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591491  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591492  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591493  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591494  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591495  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591496  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591497  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591498  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591499  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591500  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591501  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591502  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591503  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591504  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591505  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591506  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591507  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591508  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591509  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591510  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591511  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591512  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591513  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591514  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591515  14.03.2020  Everglades 50 Mile Ultra Run         50mi
#
#          race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 2591476                        40      820757              M           27
# 2591477                        40       46432              M           39
# 2591478                        40      813617              M           34
# 2591479                        40      820758              M           33
# 2591480                        40      647115              M           30
# 2591481                        40      696063              M           26
# 2591482                        40      222509              M           23
# 2591483                        40      820759              M           36
# 2591484                        40      359359              F           26
# 2591485                        40      103020              M           42
# 2591486                        40      202097              F           46
# 2591487                        40      820760              M           28
# 2591488                        40      820761              M           38
# 2591489                        40      820762              M           40
# 2591490                        40      820763              F           35
# 2591491                        40       39534              M           47
# 2591492                        40      190251              M           44
# 2591493                        40      202096              F           58
# 2591494                        40      695761              M           33
# 2591495                        40      696060              M           30
# 2591496                        40       47609              M           40
# 2591497                        40      347938              M           49
# 2591498                        40       55213              M           51
# 2591499                        40      393456              M           57
# 2591500                        40      197745              M           43
# 2591501                        40      248521              M           46
# 2591502                        40      820764              F           45
# 2591503                        40      733944              M           27
# 2591504                        40      140763              M           68
# 2591505                        40       47616              F           52
# 2591506                        40      820765              M           41
# 2591507                        40      311648              M           54
# 2591508                        40      211177              F           38
# 2591509                        40      369928              M           58
# 2591510                        40      198005              M           55
# 2591511                        40      695776              M           51
# 2591512                        40      647125              M           56
# 2591513                        40       12531              M           42
# 2591514                        40       19081              M           52
# 2591515                        40       34961              M           49
#
#         athlete_performance  athlete_average_speed
# 2591476             8:31:39                  9.436
# 2591477             8:31:48                  9.433
# 2591478             8:34:43                  9.380
# 2591479             9:07:35                  8.817
# 2591480             9:15:32                  8.691
# 2591481             9:18:05                  8.651
# 2591482             9:19:10                  8.634
# 2591483             9:20:51                  8.608
# 2591484             9:26:15                  8.526
# 2591485             9:26:16                  8.526
# 2591486             9:26:38                  8.521
# 2591487             9:34:49                  8.399
# 2591488             9:48:47                  8.200
# 2591489             9:48:47                  8.200
# 2591490            10:39:32                  7.549
# 2591491            10:39:35                  7.549
# 2591492            10:44:13                  7.494
# 2591493            10:56:52                  7.350
# 2591494            11:05:48                  7.251
# 2591495            11:09:54                  7.207
# 2591496            11:13:16                  7.171
# 2591497            11:39:29                  6.902
# 2591498            11:39:30                  6.902
# 2591499            11:42:05                  6.877
# 2591500            11:46:44                  6.831
# 2591501            11:53:44                  6.764
# 2591502            12:18:49                  6.535
# 2591503            12:32:10                  6.419
# 2591504            12:37:47                  6.371
# 2591505            12:41:43                  6.338
# 2591506            12:42:21                  6.333
# 2591507            12:48:30                  6.282
# 2591508            12:48:31                  6.282
# 2591509            12:53:43                  6.240
# 2591510            13:09:39                  6.114
# 2591511            13:42:48                  5.868
# 2591512            13:45:22                  5.850
# 2591513            13:46:59                  5.838
# 2591514            13:57:02                  5.768
# 2591515            13:57:02                  5.768

# %%
df3[df3['athlete_id'] == 211177 ]
# Out:
#            race_day                      race_name race_length  \
# 2591508  14.03.2020  Everglades 50 Mile Ultra Run         50mi
#
#          race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 2591508                        40      211177              F           38
#
#         athlete_performance  athlete_average_speed
# 2591508            12:48:31                  6.282

# %% [markdown]
# Charts / Graphs

# %%
sns.histplot(df3['race_length'])
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.histplot(df3, x ='race_length', hue = 'athlete_gender')
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.displot(df3[df3['race_length'] == '50mi']['athlete_average_speed'])

# %%
sns.violinplot(data = df3, x = 'race_length', y = 'athlete_average_speed', hue ='athlete_gender', split = True, inner= 'quart', linewidth = 2)
# Out:
# <Axes: xlabel='race_length', ylabel='athlete_average_speed'>

# %%
sns.lmplot(data=df3, x = 'athlete_age', y='athlete_average_speed')

# %%
sns.lmplot(data=df3, x = 'athlete_age', y='athlete_average_speed', hue = 'athlete_gender')
